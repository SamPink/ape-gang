# %%
from numpy import e
import requests
import pandas as pd
from parseApe import parse_ape_data
all_apes = pd.read_csv("all_the_apes.csv")

# %%
def parse_ape_canc(a):
    if a.get("asset") == None:
        return None

    return {
        "ape_id": a.get("asset").get("name"),
        "canc_event_id": a.get("id"),
        "canc_event_time": a.get("created_date"),
    }

# %%
i = 0

# %%
all_apes = pd.read_csv("all_the_apes.csv")

base = "https://api.opensea.io/api/v1/"
slug = "ape-gang"



def parse_ape(a):
    if a.get("asset") == None:
        return None

    return {
        "ape_id": a.get("asset").get("name"),
        "listing_event_id": a.get("id"),
        "listing_event_time": a.get("created_date"),
        "listing_price": (int(a.get("starting_price")) / 1000000000000000000),
    }


def parse_ape_canc(a):
    if a.get("asset") == None:
        return None

    return {
        "ape_id": a.get("asset").get("name"),
        "canc_event_id": a.get("id"),
        "canc_event_time": a.get("created_date"),
    }


def get_listings(i):
    url = f"{base}events?collection_slug={slug}&event_type=created&only_opensea=false&offset={i*50}&limit=50"
    response = requests.request("GET", url)
    return response.json()


def get_canc(i):
    url_canc = f"{base}events?collection_slug={slug}&event_type=cancelled&only_opensea=false&offset={i*50}&limit=50"
    response = requests.request("GET", url_canc)
    return response.json()

# %%
canc = get_canc(i)

# %%
canc
# Out:
# {'asset_events': [{'approved_account': None,
#    'asset': {'id': 30180927,
#     'token_id': '4981676894159712808201908443964193325271219637660871887967789093554489393153',
#     'num_sales': 3,
#     'background_color': None,
#     'image_url': 'https://lh3.googleusercontent.com/1TuUkgAIcsb03tV1rLqOOwsk_5qAgJExQVmlJ-FnpDHD339iBxVlZa83qlshb_PJ28E7IdBopfBO-Eku3tGhe3PrPM5CHSvR0_TF',
#     'image_preview_url': 'https://lh3.googleusercontent.com/1TuUkgAIcsb03tV1rLqOOwsk_5qAgJExQVmlJ-FnpDHD339iBxVlZa83qlshb_PJ28E7IdBopfBO-Eku3tGhe3PrPM5CHSvR0_TF=s250',
#     'image_thumbnail_url': 'https://lh3.googleusercontent.com/1TuUkgAIcsb03tV1rLqOOwsk_5qAgJExQVmlJ-FnpDHD339iBxVlZa83qlshb_PJ28E7IdBopfBO-Eku3tGhe3PrPM5CHSvR0_TF=s128',
#     'image_original_url': None,
#     'animation_url': None,
#     'animation_original_url': None,
#     'name': 'ApeGang #2070',
#     'description': None,
#     'external_link': None,
#     'asset_contract': {'address': '0x495f947276749ce646f68ac8c248420045cb7b5e',
# ...

# %%
def get_canc(i):
    url_canc = f"{base}events?collection_slug={slug}&event_type=cancelled&only_opensea=false&offset={i*50}&limit=50"
    response = requests.request("GET", url_canc)
    return parse_ape_canc(response.json())

# %%
canc = get_canc(i)

# %%
canc

# %%
url_canc = f"{base}events?collection_slug={slug}&event_type=cancelled&only_opensea=false&offset={i*50}&limit=50"
response = requests.request("GET", url_canc)

# %%
response.json()
# Out:
# {'asset_events': [{'approved_account': None,
#    'asset': {'id': 30354719,
#     'token_id': '4981676894159712808201908443964193325271219637660871887967796420699976892417',
#     'num_sales': 4,
#     'background_color': None,
#     'image_url': 'https://lh3.googleusercontent.com/v2oZL3uKZoBSXs-ojtwbLiCpueIhTEB0VyG1YvPeQhNZDSQPJFhFkwteRl-7-vUJbLT_veCkqhWLYZacNbxz3F-jr4m3mQt9y2iF',
#     'image_preview_url': 'https://lh3.googleusercontent.com/v2oZL3uKZoBSXs-ojtwbLiCpueIhTEB0VyG1YvPeQhNZDSQPJFhFkwteRl-7-vUJbLT_veCkqhWLYZacNbxz3F-jr4m3mQt9y2iF=s250',
#     'image_thumbnail_url': 'https://lh3.googleusercontent.com/v2oZL3uKZoBSXs-ojtwbLiCpueIhTEB0VyG1YvPeQhNZDSQPJFhFkwteRl-7-vUJbLT_veCkqhWLYZacNbxz3F-jr4m3mQt9y2iF=s128',
#     'image_original_url': None,
#     'animation_url': None,
#     'animation_original_url': None,
#     'name': 'ApeGang #8698',
#     'description': None,
#     'external_link': None,
#     'asset_contract': {'address': '0x495f947276749ce646f68ac8c248420045cb7b5e',
# ...

# %%
def get_canc(i):
    url_canc = f"{base}events?collection_slug={slug}&event_type=cancelled&only_opensea=false&offset={i*50}&limit=50"
    response = requests.request("GET", url_canc)
    return response.json()

# %%
canc

# %%
canc = get_canc(1)

# %%
canc
# Out:
# {'asset_events': [{'approved_account': None,
#    'asset': {'id': 30180927,
#     'token_id': '4981676894159712808201908443964193325271219637660871887967789093554489393153',
#     'num_sales': 3,
#     'background_color': None,
#     'image_url': 'https://lh3.googleusercontent.com/1TuUkgAIcsb03tV1rLqOOwsk_5qAgJExQVmlJ-FnpDHD339iBxVlZa83qlshb_PJ28E7IdBopfBO-Eku3tGhe3PrPM5CHSvR0_TF',
#     'image_preview_url': 'https://lh3.googleusercontent.com/1TuUkgAIcsb03tV1rLqOOwsk_5qAgJExQVmlJ-FnpDHD339iBxVlZa83qlshb_PJ28E7IdBopfBO-Eku3tGhe3PrPM5CHSvR0_TF=s250',
#     'image_thumbnail_url': 'https://lh3.googleusercontent.com/1TuUkgAIcsb03tV1rLqOOwsk_5qAgJExQVmlJ-FnpDHD339iBxVlZa83qlshb_PJ28E7IdBopfBO-Eku3tGhe3PrPM5CHSvR0_TF=s128',
#     'image_original_url': None,
#     'animation_url': None,
#     'animation_original_url': None,
#     'name': 'ApeGang #2070',
#     'description': None,
#     'external_link': None,
#     'asset_contract': {'address': '0x495f947276749ce646f68ac8c248420045cb7b5e',
# ...

# %%
canc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Samue\OneDrive\Documents\ape gang stats\opensea_events.py in <module>
# ----> 1 canc[0]
#
# KeyError: 0

# %%
def get_canc(i):
    url_canc = f"{base}events?collection_slug={slug}&event_type=cancelled&only_opensea=false&offset={i*50}&limit=50"
    response = requests.request("GET", url_canc)
    return response.json()['asset_events']

# %%
canc = get_canc(1)

# %%
canc[0]
# Out:
# {'approved_account': None,
#  'asset': {'id': 30180927,
#   'token_id': '4981676894159712808201908443964193325271219637660871887967789093554489393153',
#   'num_sales': 3,
#   'background_color': None,
#   'image_url': 'https://lh3.googleusercontent.com/1TuUkgAIcsb03tV1rLqOOwsk_5qAgJExQVmlJ-FnpDHD339iBxVlZa83qlshb_PJ28E7IdBopfBO-Eku3tGhe3PrPM5CHSvR0_TF',
#   'image_preview_url': 'https://lh3.googleusercontent.com/1TuUkgAIcsb03tV1rLqOOwsk_5qAgJExQVmlJ-FnpDHD339iBxVlZa83qlshb_PJ28E7IdBopfBO-Eku3tGhe3PrPM5CHSvR0_TF=s250',
#   'image_thumbnail_url': 'https://lh3.googleusercontent.com/1TuUkgAIcsb03tV1rLqOOwsk_5qAgJExQVmlJ-FnpDHD339iBxVlZa83qlshb_PJ28E7IdBopfBO-Eku3tGhe3PrPM5CHSvR0_TF=s128',
#   'image_original_url': None,
#   'animation_url': None,
#   'animation_original_url': None,
#   'name': 'ApeGang #2070',
#   'description': None,
#   'external_link': None,
#   'asset_contract': {'address': '0x495f947276749ce646f68ac8c248420045cb7b5e',
#    'asset_contract_type': 'semi-fungible',
# ...

# %%
parse_ape_canc(canc[0])
# Out:
# {'ape_id': 'ApeGang #2070',
#  'canc_event_id': 1373896511,
#  'canc_event_time': '2021-10-14T20:52:32.091198'}

# %%
thing = parse_ape_canc(canc[0])

# %%
df = pd.DataFrame(thing)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Samue\OneDrive\Documents\ape gang stats\opensea_events.py in <module>
# ----> 1 df = pd.DataFrame(thing)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ...

# %%
df = pd.DataFrame(thing, index=[0])

# %%
df
# Out:
#           ape_id  canc_event_id             canc_event_time
# 0  ApeGang #2070     1373896511  2021-10-14T20:52:32.091198

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 0 to 0
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ape_id           1 non-null      object
#  1   canc_event_id    1 non-null      int64
#  2   canc_event_time  1 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 32.0+ bytes

# %%
df['canc_event_time'] = df['canc_event_time'].astype('datetime64[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 0 to 0
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ape_id           1 non-null      object
#  1   canc_event_id    1 non-null      int64
#  2   canc_event_time  1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 32.0+ bytes

# %%
all_apes = pd.read_csv("all_the_apes.csv")

# %%
all_apes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10000 non-null  int64
#  1   ape_id      10000 non-null  object
#  2   Clothes     7798 non-null   object
#  3   Ears        2435 non-null   object
#  4   Hat         6904 non-null   object
#  5   Fur         10000 non-null  object
#  6   Mouth       6860 non-null   object
#  7   Eyes        6896 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 625.1+ KB

# %%
all_apes = pd.read_csv("apes_with_listings.csv")

# %%
all_apes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12172 entries, 0 to 12171
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          12172 non-null  int64
#  1   Unnamed: 0.1        12172 non-null  int64
#  2   ape_id              12172 non-null  object
#  3   Clothes             9447 non-null   object
#  4   Ears                2961 non-null   object
#  5   Hat                 8326 non-null   object
#  6   Fur                 12172 non-null  object
#  7   Mouth               8338 non-null   object
#  8   Eyes                8335 non-null   object
#  9   listing_event_id    4010 non-null   float64
#  10  listing_event_time  4010 non-null   object
#  11  listing_price       4010 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
all_apes['listing_event_time'] = all_apes['listing_event_time'].astype('datetime64[ns]')

# %%
all_apes['apes_id'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'apes_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Samue\OneDrive\Documents\ape gang stats\opensea_events.py in <module>
# ...

# %%
all_apes
# Out:
#        Unnamed: 0  Unnamed: 0.1         ape_id             Clothes  \
# 0               0             0  ApeGang #9211            Magician
# 1               1             1  ApeGang #9195   Yellow NBA Jersey
# 2               2             2  ApeGang #9190            Military
# 3               3             3  ApeGang #9181                Toga
# 4               4             4  ApeGang #9154              Hippie
# ...           ...           ...            ...                 ...
# 12167       12167          9995     ApeGang #4  Red Hawaiian Shirt
# 12168       12168          9996     ApeGang #3                 NaN
# 12169       12169          9997     ApeGang #2            Military
# 12170       12170          9998     ApeGang #1      Red NBA Jersey
# 12171       12171          9999     ApeGang #0  Red Hawaiian Shirt
#
#                      Ears            Hat                Fur          Mouth  \
# 0               Gold Hoop         Banana  Strong Dark Brown        Shocked
# ...

# %%
all_apes.ape_id
# Out:
# 0        ApeGang #9211
# 1        ApeGang #9195
# 2        ApeGang #9190
# 3        ApeGang #9181
# 4        ApeGang #9154
#              ...
# 12167       ApeGang #4
# 12168       ApeGang #3
# 12169       ApeGang #2
# 12170       ApeGang #1
# 12171       ApeGang #0
# Name: ape_id, Length: 12172, dtype: object

# %%
all_apes.ape_id[0]
# Out:
# 'ApeGang #9211'

# %%
all_apes.ape_id[0].str
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Samue\OneDrive\Documents\ape gang stats\opensea_events.py in <module>
# ----> 1 all_apes.ape_id[0].str
#
# AttributeError: 'str' object has no attribute 'str'

# %%
type(all_apes.ape_id[0])
# Out:
# str

# %%
all_apes.ape_id[0].split('#')
# Out:
# ['ApeGang ', '9211']

# %%
all_apes.ape_id[0].split('#')[1]
# Out:
# '9211'

# %%
all_apes.ape_id = all_apes.ape_id[0].split('#')[1]

# %%
all_apes
# Out:
#        Unnamed: 0  Unnamed: 0.1 ape_id             Clothes  \
# 0               0             0   9211            Magician
# 1               1             1   9211   Yellow NBA Jersey
# 2               2             2   9211            Military
# 3               3             3   9211                Toga
# 4               4             4   9211              Hippie
# ...           ...           ...    ...                 ...
# 12167       12167          9995   9211  Red Hawaiian Shirt
# 12168       12168          9996   9211                 NaN
# 12169       12169          9997   9211            Military
# 12170       12170          9998   9211      Red NBA Jersey
# 12171       12171          9999   9211  Red Hawaiian Shirt
#
#                      Ears            Hat                Fur          Mouth  \
# 0               Gold Hoop         Banana  Strong Dark Brown        Shocked
# 1                     NaN  Viking Helmet              Brown          Joint
# ...

# %%
df
# Out:
#           ape_id  canc_event_id            canc_event_time
# 0  ApeGang #2070     1373896511 2021-10-14 20:52:32.091198

# %%
df.ape_id = df.ape_id[0].split('#')[1]

# %%
all_apes[all_apes.ape_id == 2070]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, ape_id, Clothes, Ears, Hat, Fur, Mouth, Eyes, listing_event_id, listing_event_time, listing_price]
# Index: []

# %%
all_apes[all_apes.ape_id == '2070']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, ape_id, Clothes, Ears, Hat, Fur, Mouth, Eyes, listing_event_id, listing_event_time, listing_price]
# Index: []

# %%
all_apes.ape_id
# Out:
# 0        9211
# 1        9211
# 2        9211
# 3        9211
# 4        9211
#          ...
# 12167    9211
# 12168    9211
# 12169    9211
# 12170    9211
# 12171    9211
# Name: ape_id, Length: 12172, dtype: object

# %%
all_apes.ape_id[0]
# Out:
# '9211'

# %%
all_apes[all_apes.ape_id == '1']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, ape_id, Clothes, Ears, Hat, Fur, Mouth, Eyes, listing_event_id, listing_event_time, listing_price]
# Index: []

# %%
all_apes.ape_id
# Out:
# 0        9211
# 1        9211
# 2        9211
# 3        9211
# 4        9211
#          ...
# 12167    9211
# 12168    9211
# 12169    9211
# 12170    9211
# 12171    9211
# Name: ape_id, Length: 12172, dtype: object
