# %%
import pandas as pd

# %%
df = pd.read_csv('../csvs/apes_with_listings.csv')

# %%
df.sort_values('listing_event_time', ascending=False)
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 2448        2448          2448            2448              2448
# 1317        1317          1317            1317              1317
# 7217        7217          7217            7217              7217
# 4094        4094          4094            4094              4094
# 6466        6466          6466            6466              6466
# ...          ...           ...             ...               ...
# 9993        9993          9993            9993              9993
# 9994        9994          9994            9994              9994
# 9996        9996          9996            9996              9996
# 9997        9997          9997            9997              9997
# 9998        9998          9998            9998              9998
#
#              ape_id         Clothes          Ears           Hat  \
# 2448  ApeGang #7554     Winter Coat           NaN    Sushi Chef
# 1317  ApeGang #8685             NaN           NaN  Brown Beanie
# 7217  ApeGang #2815             Cop  Diamond Stud           NaN
# 4094  ApeGang #5911     Devil Wings           NaN           NaN
# 6466  ApeGang #3533        Iron Man           NaN        Chef's
# ...             ...             ...           ...           ...
# 9993     ApeGang #6      Lumberjack           NaN       Bandana
# 9994     ApeGang #5    Banana Shirt           NaN           NaN
# 9996     ApeGang #3             NaN   Silver Hoop        Chef's
# 9997     ApeGang #2        Military  Diamond Stud          Halo
# 9998     ApeGang #1  Red NBA Jersey  Diamond Stud         Party
#
#                     Fur          Mouth              Eyes  listing_event_id  \
# 2448              Zebra            NaN     Round Glasses      1.455046e+09
# 1317              Cream          Angry     Robot Glasses      1.454883e+09
# 7217              Black  Drool Rainbow               NaN      1.454796e+09
# 4094              Brown          Angry           Monocle      1.454762e+09
# 6466              Tiger   Grin Rainbow       Diving Mask      1.454753e+09
# ...                 ...            ...               ...               ...
# 9993              Black         Flames  Black Sunglasses               NaN
# 9994  Strong Dark Brown            NaN               NaN               NaN
# 9996              Cream  Drool Rainbow        3D Glasses               NaN
# 9997              Cream            NaN     Robot Glasses               NaN
# 9998              Zebra  Baby Pacifier               Sad               NaN
#
#               listing_event_time  listing_price
# 2448  2021-10-20 07:13:09.373034          0.850
# 1317  2021-10-20 06:57:13.166920          0.900
# 7217  2021-10-20 06:48:52.945100          0.777
# 4094  2021-10-20 06:45:45.229975          4.300
# 6466  2021-10-20 06:44:52.982721          1.600
# ...                          ...            ...
# 9993                         NaN            NaN
# 9994                         NaN            NaN
# 9996                         NaN            NaN
# 9997                         NaN            NaN
# 9998                         NaN            NaN
#
# [10000 rows x 14 columns]

# %%
df[df.ape_id == 'ApeGang #9273']
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1         ape_id       Clothes  \
# 737         737           737             737  ApeGang #9273  Hotel Porter
#
#     Ears      Hat    Fur      Mouth   Eyes  listing_event_id  \
# 737  NaN  Fireman  Brown  Nose Ring  Heart      1.441861e+09
#
#              listing_event_time  listing_price
# 737  2021-10-19 11:24:06.317005           0.85
